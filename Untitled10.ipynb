# %%
#List in python And its methods

# %%
Fruits = ['Apple', 'mango', 'bannana']

# %%
Fruits.append('watermelon')

# %%
Fruits
# Out:
# ['Apple', 'mango', 'bannana', 'watermelon']

# %%
Fruits.sort()

# %%
Fruits
# Out:
# ['Apple', 'bannana', 'mango', 'watermelon']

# %%
Fruits.reverse()

# %%
Fruits
# Out:
# ['watermelon', 'mango', 'bannana', 'Apple']

# %%
Fruits.remove('watermelon')
Fruits
# Out:
# ['mango', 'bannana', 'Apple']

# %%
Fruits.pop(1)
# Out:
# 'bannana'

# %%
Fruits.insert(1,'watermelon')

# %%
Fruits
# Out:
# ['mango', 'watermelon', 'Apple']

# %%
others = ['dragonfruit', 'guvava', 'papaya']

# %%
Fruits.extend(others)
Fruits
# Out:
# ['mango', 'watermelon', 'Apple', 'dragonfruit', 'guvava', 'papaya']

# %%
Fruits.count('Apple')
# Out:
# 1

# %%
Fruits.copy()
# Out:
# ['mango', 'watermelon', 'Apple', 'dragonfruit', 'guvava', 'papaya']
